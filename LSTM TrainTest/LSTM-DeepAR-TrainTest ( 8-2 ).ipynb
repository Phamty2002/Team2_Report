# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
df = pd.read_csv("D:VOF.L.csv",index_col = "Date",parse_dates = True)

# %%
df
# Out:
#              Open        High         Low   Close   Adj Close  Volume
# Date
# 2017-01-03  272.0  275.000000  272.000000  273.25  233.939148  170046
# 2017-01-04  272.0  275.000000  272.000000  272.75  233.511093  107823
# 2017-01-05  272.0  274.500000  270.250000  272.50  233.297043  391623
# 2017-01-06  272.5  273.750000  266.000000  273.00  233.725098  464329
# 2017-01-09  273.0  273.500000  270.000000  273.50  234.153183  276108
# ...           ...         ...         ...     ...         ...     ...
# 2022-03-25  502.0  507.000000  502.000000  507.00  493.078217  265108
# 2022-03-28  502.0  511.000000  502.000000  506.00  492.105652  115303
# 2022-03-29  502.0  520.000000  500.000000  518.00  503.776154  149574
# 2022-03-30  516.0  516.989990  507.666992  513.00  498.913422   65890
# 2022-03-31  514.0  516.588989  506.000000  506.00  492.105652   68055
#
# [1328 rows x 6 columns]

# %%
def preprocess_lstm(sequence, n_steps,n_features):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix >= len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
        
    X = np.array(X)
    y = np.array(y)

    X = X.reshape((X.shape[0], X.shape[1], n_features))
    return X, y

# %%
df_close = df['Close']

plt.figure(figsize=(10,6))
plt.grid()
plt.plot(df_close)
plt.xlabel('Date')
plt.ylabel('Closing Prices')
plt.title('VNC stock closing price')
# Out:
# Text(0.5, 1.0, 'VNC stock closing price')

# %%
dataset = df.values
sc = MinMaxScaler(feature_range = (0,1))
data_scaled = sc.fit_transform(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\2950502552.py in <module>
#       1 dataset = df.values
# ----> 2 sc = MinMaxScaler(feature_range = (0,1))
#       3 data_scaled = sc.fit_transform(dataset)
#
# NameError: name 'MinMaxScaler' is not defined

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM, Flatten
from keras.layers import ConvLSTM2D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [raw]
# dataset = df.values
# sc = MinMaxScaler(feature_range = (0,1))
# data_scaled = sc.fit_transform(dataset)

# %%
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\3050397949.py in <module>
#       2 y_train = []
#       3
# ----> 4 for i in range(60, len(train_data)):
#       5     x_train.append(train_data[i-60:i, 0])
#       6     y_train.append(train_data[i, 0])
#
# NameError: name 'train_data' is not defined

# %%
close_prices = stock_data['Close']
values = close_prices.values
training_data_len = math.ceil(len(values)* 0.8)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(values.reshape(-1,1))
train_data = scaled_data[0: training_data_len, :]

x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\3847884776.py in <module>
# ----> 1 close_prices = stock_data['Close']
#       2 values = close_prices.values
#       3 training_data_len = math.ceil(len(values)* 0.8)
#       4
#       5 scaler = MinMaxScaler(feature_range=(0,1))
#
# NameError: name 'stock_data' is not defined

# %%
close_prices = df['Close']
values = close_prices.values
training_data_len = math.ceil(len(values)* 0.8)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(values.reshape(-1,1))
train_data = scaled_data[0: training_data_len, :]

x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
test_data = scaled_data[training_data_len-60: , : ]
x_test = []
y_test = values[training_data_len:]

for i in range(60, len(test_data)):
  x_test.append(test_data[i-60:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
model = keras.Sequential()
model.add(layers.LSTM(100, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(layers.LSTM(100, return_sequences=False))
model.add(layers.Dense(25))
model.add(layers.Dense(1))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\2367720424.py in <module>
#       1 model = keras.Sequential()
# ----> 2 model.add(layers.LSTM(100, return_sequences=True, input_shape=(x_train.shape[1], 1)))
#       3 model.add(layers.LSTM(100, return_sequences=False))
#       4 model.add(layers.Dense(25))
#       5 model.add(layers.Dense(1))
#
# NameError: name 'layers' is not defined

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import math
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.prepro
# Out:
#   File "C:\Users\Administrator\AppData\Local\Temp\ipykernel_19908\3374556995.py", line 5
#     from sklearn.prepro
#                        ^
# SyntaxError: invalid syntax

# %%
model = keras.Sequential()
model.add(layers.LSTM(100, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(layers.LSTM(100, return_sequences=False))
model.add(layers.Dense(25))
model.add(layers.Dense(1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 100)           40800
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 25)                2525
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 123,751
# Trainable params: 123,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, batch_size= 1, epochs=3)
# Out:
# Epoch 1/3
# 1003/1003 [==============================] - 30s 26ms/step - loss: 0.0015
# Epoch 2/3
# 1003/1003 [==============================] - 23s 22ms/step - loss: 5.1457e-04
# Epoch 3/3
# 1003/1003 [==============================] - 24s 24ms/step - loss: 4.3240e-04

# %%
#RMSE
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("RMSE: ", rmse)
#MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print("MAPE: ", mape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\1950881469.py in <module>
#       1 #RMSE
# ----> 2 rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
#       3 print("RMSE: ", rmse)
#       4 #MAPE
#       5 mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
#
# NameError: name 'predictions' is not defined

# %%
predictions = model.predict(x_test)
predictions = sc.inverse_transform(predictions)
# Out:
# 9/9 [==============================] - 1s 29ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\899274633.py in <module>
#       1 predictions = model.predict(x_test)
# ----> 2 predictions = sc.inverse_transform(predictions)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     527         )
#     528
# --> 529         X -= self.min_
#     530         X /= self.scale_
#     531         return X
#
# ValueError: non-broadcastable output operand with shape (265,1) doesn't match the broadcast shape (265,6)

# %%
#RMSE
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
print("RMSE: ", rmse)
#MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print("MAPE: ", mape)
# Out:
# RMSE:  479.27048999478
# MAPE:  99.8249900316139

# %%
#Plot the data
train_ = df[:training_data_len]
test_ =  df[training_data_len:]
test_['Predictions'] = predictions
#Visualisze the data
plt.figure(figsize = (12,5))
plt.title("VNC's Stock Price Trainning")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(train_['Close'])
plt.plot(test_[['Close', 'Predictions']])
plt.legend(['Train', 'Test', 'LSTM Predictions'], loc = 'upper left')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19908\883257517.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_['Predictions'] = predictions
